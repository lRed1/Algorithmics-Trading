# %%
import datetime as dt
import pandas as pd
import yfinance as yf

# %%
tickers = ["AMZN","META","TSLA", "GOOG"]
start = dt.datetime.today() - dt.timedelta(3650)
end = dt.datetime.today()
cl_price = pd.DataFrame()

# %%
for ticker in tickers:
    cl_price[ticker] = yf.download(ticker,start,end)["Adj Close"]

# %%
cl_price.dropna(axis = 0, how = "any", inplace = True)

# %%
daily_return = cl_price.pct_change()

# %%
cl_price.plot()

# %%
cl_price.plot(subplots = True, layout= (2,2))

# %%
cl_price.plot(subplots = True, layout= (2,2), title = "Stock Price Evolution")

# %%
cl_price.plot(subplots = True, layout= (2,2), title = "Stock Price Evolution", grid = True)

# %%
daily_return.plot(subplots = True, layout= (2,2), title = "Stock Price Evolution", grid = True)

# %%
(1 + daily_return).cumprod().plot()
(1+daily_return).cumsum()
# Out:
#                    AMZN         META         TSLA         GOOG
# Date
# 2013-09-23          NaN          NaN          NaN          NaN
# 2013-09-24     1.008475     1.026701     1.006736     1.000383
# 2013-09-25     2.003764     2.047547     2.022696     1.989547
# 2013-09-26     3.021260     3.066350     3.041051     2.990619
# 2013-09-27     4.014627     4.083218     4.053031     3.988592
# ...                 ...          ...          ...          ...
# 2023-09-14  2513.776499  2513.606867  2515.707285  2513.227851
# 2023-09-15  2514.746579  2514.570264  2516.701308  2514.222886
# 2023-09-18  2515.743658  2515.577723  2517.668107  2515.227659
# 2023-09-19  2516.726870  2516.586052  2518.672706  2516.226723
# 2023-09-20  2517.709868  2517.568351  2519.658034  2517.196182
#
# [2516 rows x 4 columns]
