# %%
import datetime as dt
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
tickers = ["AMZN","META","TSLA", "GOOG"]
start = dt.datetime.today() - dt.timedelta(3650)
end = dt.datetime.today()
cl_price = pd.DataFrame()

# %%
for ticker in tickers:
    cl_price[ticker] = yf.download(ticker,start,end)["Adj Close"]
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
cl_price.dropna(axis = 0, how = "any", inplace = True)

# %%
daily_return = cl_price.pct_change()

# %%
fig, ax = plt.subplots()
plt.style.available
plt.style.use("ggplot")
ax.set(title = "Mean Daily Return of Stocks", xlabel = "Stocks", ylabel = "Mean Return")
plt.bar(x = daily_return.columns, height = daily_return.mean())
plt.bar(x = daily_return.columns, height = daily_return.std(), color =  ["red", "blue", "green", "orange"])
# Out:
# <BarContainer object of 4 artists>
